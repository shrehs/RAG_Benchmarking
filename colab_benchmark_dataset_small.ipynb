# %% [markdown]
# <a href="https://colab.research.google.com/github/shrehs/RAG_Benchmarking/blob/main/colab_benchmark_dataset_small.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # RAG Benchmark — Google Colab Runner
#
# **Stack**
# | Component | Choice |
# |-----------|--------|
# | Generator LLM | `llama-3.1-8b-instant` via Groq (free, fast) |
# | Judge LLM | `llama-3.3-70b-versatile` via Groq (free, stronger) |
# | Embeddings | `BAAI/bge-large-en-v1.5` — runs on T4 GPU |
# | Vector store | FAISS (exact search) |
# | Evaluation | RAGAS (faithfulness + answer relevancy) |
#
# **Before running:**
# 1. Runtime → Change runtime type → **T4 GPU**
# 2. Open the 🔑 Secrets panel (left sidebar) and add:
#    - `GROQ_API_KEY` — free key from [console.groq.com](https://console.groq.com)
#    - `GITHUB_TOKEN` — a GitHub personal access token with `repo` scope (for pushing results)
# 3. Run cells top to bottom.

# %% [markdown]
# ## 1 · Clone repository

# %%
# ── Change this to your repo ──────────────────────────────────────────────────
GITHUB_USER = "shrehs"          # e.g. "shreya"
REPO_NAME   = "RAG_Benchmarking"          # e.g. "rag-benchmark"
BRANCH      = "main"
# ─────────────────────────────────────────────────────────────────────────────

import os
from google.colab import userdata

GITHUB_TOKEN = userdata.get("GITHUB_TOKEN")
REPO_URL = f"https://{GITHUB_TOKEN}@github.com/{GITHUB_USER}/{REPO_NAME}.git"

# Clone (or pull if already cloned from a previous session)
if not os.path.exists(f"/content/{REPO_NAME}/.git"):
    # !git clone --branch {BRANCH} {REPO_URL} /content/{REPO_NAME}
else:
    # !git -C /content/{REPO_NAME} pull

# %cd /content/{REPO_NAME}
print(f"Working directory: {os.getcwd()}")
# Out:
# Already up to date.
# /content/RAG_Benchmarking
# Working directory: /content/RAG_Benchmarking

# %% [markdown]
# ## 2 · Install dependencies

# %%
# %%capture install_output
# Colab already has torch + numpy; install project-specific packages
# !pip install -q \
    groq \
    langchain-groq \
    langchain \
    langchain-community \
    langchain-huggingface \
    faiss-cpu \
    sentence-transformers \
    rank-bm25 \
    spacy \
    networkx \
    ragas \
    datasets \
    wikipedia-api \
    arxiv \
    psutil \
    python-dotenv \
    tiktoken

# !python -m spacy download -q en_core_web_sm

print("Dependencies installed.")

# %% [markdown]
# ## 3 · Configure secrets

# %%
import os
from google.colab import userdata

os.environ["GROQ_API_KEY"] = userdata.get("GROQ_API_KEY")

# Sanity check — never print the actual key
key = os.environ.get("GROQ_API_KEY", "")
print(f"GROQ_API_KEY set: {'yes (' + key[:8] + '...)' if key else 'NO — check Secrets'}")
# Out:
# GROQ_API_KEY set: yes (gsk_slcI...)

# %% [markdown]
# ## 4 · Verify environment

# %%
import torch, psutil

gpu = torch.cuda.get_device_name(0) if torch.cuda.is_available() else "None (CPU only)"
ram_gb = psutil.virtual_memory().total / 1e9

print(f"GPU  : {gpu}")
print(f"RAM  : {ram_gb:.1f} GB")
print(f"CUDA : {torch.version.cuda}")

# Confirm bge-large will use GPU
print(f"\nEmbeddings will use: {'CUDA (GPU)' if torch.cuda.is_available() else 'CPU'}")
# Out:
# GPU  : Tesla T4
# RAM  : 13.6 GB
# CUDA : 12.8
#
# Embeddings will use: CUDA (GPU)

# %%
# !git pull
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 543 bytes | 543.00 KiB/s, done.
# From https://github.com/shrehs/RAG_Benchmarking
#    e06a845..c918725  main       -> origin/main
# Updating e06a845..c918725
# Fast-forward
#  evaluation/ragas_eval.py | 4 ++--
#  1 file changed, 2 insertions(+), 2 deletions(-)

# %% [markdown]
# ## 5 · Run benchmark
#
# Choose dataset: `small` (50 Wikipedia articles) · `medium` (500 arXiv papers) · `large` (2400 Kubernetes docs)

# %%
DATASET = "small"   # change to "medium" or "large" as needed

# !python run_benchmark.py --dataset {DATASET}
# Out:
# ============================================================
# RAG BENCHMARK — 5 experiments
# Started: 2026-03-16 18:33 UTC
# Dry run: False
# ============================================================
#
# [checkpoint] ✓ VECTOR × SMALL already completed (RUN-001) — skipping
#
# ============================================================
# RUN-002 | HYBRID × SMALL
# ============================================================
# [run] Loading dataset: small
# [run] Loaded 50 documents
# [run] Loaded 20 QA pairs from cache
# [run] Loading cached index from /content/RAG_Benchmarking/results/indexes/hybrid/small
# [run] Measuring latency...
# [latency] Running 1 warmup queries...
# [embedder] Loading BAAI/bge-large-en-v1.5 on cpu...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100% 391/391 [00:00<00:00, 1059.66it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: BAAI/bge-large-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# [latency] Running 5 timed queries...
# [latency] P50=0.433s  P95=0.478s  Throughput=2.3q/s  Peak RAM=2085MB
# [run] Computing retrieval metrics...
# [run] Running RAGAS evaluation...
# /usr/local/lib/python3.12/dist-packages/instructor/providers/gemini/client.py:5: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   import google.generativeai as genai  # type: ignore[import-not-found]
# [ragas_eval] Evaluating 20 QA pairs with judge=llama-3.1-8b-instant...
# [ragas_eval] 10/20 queries processed...
# [ragas_eval] 20/20 queries processed...
# Loading weights: 100% 391/391 [00:00<00:00, 926.88it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: BAAI/bge-large-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Evaluating:   0% 0/20 [00:00<?, ?it/s]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:   5% 1/20 [00:01<00:32,  1.73s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  10% 2/20 [00:11<01:56,  6.45s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  15% 3/20 [00:15<01:27,  5.16s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  20% 4/20 [00:19<01:19,  4.97s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  25% 5/20 [00:23<01:07,  4.49s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  30% 6/20 [00:27<01:02,  4.49s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  35% 7/20 [00:31<00:55,  4.24s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  40% 8/20 [00:36<00:52,  4.41s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  45% 9/20 [00:41<00:50,  4.60s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  50% 10/20 [00:45<00:42,  4.29s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  55% 11/20 [00:48<00:36,  4.11s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  60% 12/20 [00:53<00:34,  4.36s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  65% 13/20 [00:57<00:28,  4.09s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  70% 14/20 [01:00<00:24,  4.00s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  75% 15/20 [01:05<00:21,  4.27s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  80% 16/20 [01:09<00:16,  4.15s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  85% 17/20 [01:13<00:11,  3.97s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  90% 18/20 [01:18<00:08,  4.27s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  95% 19/20 [01:22<00:04,  4.13s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating: 100% 20/20 [01:25<00:00,  4.29s/it]
# [log_results] ✅ Appended RUN-002 to /content/RAG_Benchmarking/decisions_log.md
#
# [run] ✅ RUN-002 complete
# [run]    Recall@5: 0.0000
# [run]    P50 Latency: 0.433s
# [run]    Faithfulness: 0.0000
# [run]    Results: /content/RAG_Benchmarking/results/benchmark_tables/run_002_hybrid_small.json
#
# ============================================================
# RUN-003 | GRAPH × SMALL
# ============================================================
# [run] Loading dataset: small
# [run] Loaded 50 documents
# [run] Loaded 20 QA pairs from cache
# [run] Building index...
# [GraphRAG] Indexing 50 documents...
# [GraphRAG] 115 chunks — extracting entities...
# [GraphRAG] 165 valid entities (freq >= 2) from 734 total
# [GraphRAG] Graph: 165 nodes, 1068 edges
# [run] Indexing complete in 8.3s
# [run] Measuring latency...
# [latency] Running 1 warmup queries...
# [latency] Running 5 timed queries...
# [latency] P50=0.011s  P95=0.014s  Throughput=101.8q/s  Peak RAM=3519MB
# [run] Computing retrieval metrics...
# [run] Running RAGAS evaluation...
# [ragas_eval] Evaluating 20 QA pairs with judge=llama-3.1-8b-instant...
# [ragas_eval] 10/20 queries processed...
# [ragas_eval] 20/20 queries processed...
# Loading weights: 100% 391/391 [00:00<00:00, 1095.76it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: BAAI/bge-large-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Evaluating:   0% 0/20 [00:00<?, ?it/s]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:   5% 1/20 [00:02<00:51,  2.69s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  10% 2/20 [00:06<01:03,  3.53s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  15% 3/20 [00:10<01:00,  3.57s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  20% 4/20 [00:15<01:04,  4.01s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  25% 5/20 [00:19<01:00,  4.04s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  30% 6/20 [00:22<00:54,  3.91s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  35% 7/20 [00:27<00:53,  4.15s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  40% 8/20 [00:31<00:49,  4.12s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  45% 9/20 [00:36<00:47,  4.31s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  50% 10/20 [00:39<00:41,  4.12s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  55% 11/20 [00:43<00:36,  4.05s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  60% 12/20 [00:47<00:31,  3.90s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  65% 13/20 [00:52<00:28,  4.13s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  70% 14/20 [00:55<00:24,  4.05s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  75% 15/20 [00:59<00:19,  3.92s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  80% 16/20 [01:04<00:16,  4.20s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  85% 17/20 [01:08<00:12,  4.08s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  90% 18/20 [01:11<00:07,  3.94s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  95% 19/20 [01:16<00:04,  4.18s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating: 100% 20/20 [01:20<00:00,  4.02s/it]
# [log_results] ✅ Appended RUN-003 to /content/RAG_Benchmarking/decisions_log.md
#
# [run] ✅ RUN-003 complete
# [run]    Recall@5: 0.0000
# [run]    P50 Latency: 0.011s
# [run]    Faithfulness: 0.0000
# [run]    Results: /content/RAG_Benchmarking/results/benchmark_tables/run_003_graph_small.json
#
# ============================================================
# RUN-004 | PARENT_CHILD × SMALL
# ============================================================
# [run] Loading dataset: small
# [run] Loaded 50 documents
# [run] Loaded 20 QA pairs from cache
# [run] Building index...
# [ParentChildRAG] Indexing 50 documents...
# [ParentChildRAG] 57 parents, 214 children
# [embedder] Loading BAAI/bge-large-en-v1.5 on cpu...
# Loading weights: 100% 391/391 [00:00<00:00, 1003.84it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: BAAI/bge-large-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Batches: 100% 7/7 [03:29<00:00, 30.00s/it]
# Batches: 100% 7/7 [03:15<00:00, 27.89s/it]
# [ParentChildRAG] FAISS index built on 214 child vectors
# [run] Indexing complete in 433.2s
# [run] Measuring latency...
# [latency] Running 1 warmup queries...
# [latency] Running 5 timed queries...
# [latency] P50=0.432s  P95=0.483s  Throughput=2.3q/s  Peak RAM=3946MB
# [run] Computing retrieval metrics...
# [run] Running RAGAS evaluation...
# [ragas_eval] Evaluating 20 QA pairs with judge=llama-3.1-8b-instant...
# [ragas_eval] 10/20 queries processed...
# [ragas_eval] 20/20 queries processed...
# Loading weights: 100% 391/391 [00:00<00:00, 905.49it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: BAAI/bge-large-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Evaluating:   0% 0/20 [00:00<?, ?it/s]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:   5% 1/20 [00:02<00:56,  2.95s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  10% 2/20 [00:09<01:35,  5.31s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  15% 3/20 [00:13<01:17,  4.54s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  20% 4/20 [00:18<01:12,  4.56s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  25% 5/20 [00:21<01:04,  4.27s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  30% 6/20 [00:26<01:01,  4.39s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  35% 7/20 [00:30<00:54,  4.17s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  40% 8/20 [00:33<00:48,  4.03s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  45% 9/20 [00:38<00:46,  4.20s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  50% 10/20 [00:43<00:43,  4.34s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  55% 11/20 [00:47<00:39,  4.44s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  60% 12/20 [00:51<00:33,  4.16s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  65% 13/20 [00:55<00:28,  4.02s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  70% 14/20 [00:59<00:25,  4.20s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  75% 15/20 [01:03<00:20,  4.02s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  80% 16/20 [01:08<00:17,  4.35s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  85% 17/20 [01:12<00:12,  4.14s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  90% 18/20 [01:15<00:07,  3.98s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  95% 19/20 [01:20<00:04,  4.24s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating: 100% 20/20 [01:24<00:00,  4.20s/it]
# [log_results] ✅ Appended RUN-004 to /content/RAG_Benchmarking/decisions_log.md
#
# [run] ✅ RUN-004 complete
# [run]    Recall@5: 0.0000
# [run]    P50 Latency: 0.432s
# [run]    Faithfulness: 0.0000
# [run]    Results: /content/RAG_Benchmarking/results/benchmark_tables/run_004_parent_child_small.json
#
# ============================================================
# RUN-005 | MULTI_QUERY × SMALL
# ============================================================
# [run] Loading dataset: small
# [run] Loaded 50 documents
# [run] Loaded 20 QA pairs from cache
# [run] Building index...
# [MultiQueryRAG] Indexing 50 documents...
# [MultiQueryRAG] 115 chunks
# [embedder] Loading BAAI/bge-large-en-v1.5 on cpu...
# Loading weights: 100% 391/391 [00:00<00:00, 934.28it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: BAAI/bge-large-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Batches: 100% 7/7 [05:09<00:00, 44.28s/it]
# [MultiQueryRAG] FAISS index built: 115 vectors
# [run] Indexing complete in 360.4s
# [run] Measuring latency...
# [latency] Running 1 warmup queries...
# [latency] Running 5 timed queries...
# [latency] P50=1.886s  P95=2.011s  Throughput=0.6q/s  Peak RAM=6373MB
# [run] Computing retrieval metrics...
# [run] Running RAGAS evaluation...
# [ragas_eval] Evaluating 20 QA pairs with judge=llama-3.1-8b-instant...
# [ragas_eval] 10/20 queries processed...
# [ragas_eval] 20/20 queries processed...
# Loading weights: 100% 391/391 [00:00<00:00, 1075.79it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: BAAI/bge-large-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Evaluating:   0% 0/20 [00:00<?, ?it/s]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:   5% 1/20 [00:03<01:11,  3.76s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  10% 2/20 [00:09<01:28,  4.92s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  15% 3/20 [00:14<01:22,  4.83s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  20% 4/20 [00:18<01:10,  4.42s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  25% 5/20 [00:23<01:09,  4.64s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  30% 6/20 [00:26<01:00,  4.33s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  35% 7/20 [00:30<00:53,  4.11s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  40% 8/20 [00:34<00:48,  4.00s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  45% 9/20 [00:38<00:46,  4.20s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  50% 10/20 [00:42<00:40,  4.03s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  55% 11/20 [00:47<00:39,  4.34s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  60% 12/20 [00:51<00:32,  4.12s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  65% 13/20 [00:54<00:27,  3.94s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  70% 14/20 [00:59<00:25,  4.23s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  75% 15/20 [01:03<00:20,  4.02s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  80% 16/20 [01:07<00:16,  4.21s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  85% 17/20 [01:11<00:12,  4.03s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  90% 18/20 [01:15<00:07,  3.92s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  95% 19/20 [01:19<00:04,  4.14s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating: 100% 20/20 [01:23<00:00,  4.16s/it]
# [log_results] ✅ Appended RUN-005 to /content/RAG_Benchmarking/decisions_log.md
#
# [run] ✅ RUN-005 complete
# [run]    Recall@5: 0.0000
# [run]    P50 Latency: 1.886s
# [run]    Faithfulness: 0.0000
# [run]    Results: /content/RAG_Benchmarking/results/benchmark_tables/run_005_multi_query_small.json
#
# ============================================================
# ALL RUNS COMPLETE
# Summary: /content/RAG_Benchmarking/results/benchmark_tables/summary.json
# Full log: decisions_log.md
# ============================================================
#
# Architecture       Dataset    Recall@5     P50 (s)    Faith.     $/query
# ------------------------------------------------------------------------
# vector             small      0.0000       0.489      0.9769     0.000178
# hybrid             small      0.0000       0.433      0.0000     0.000180
# graph              small      0.0000       0.011      0.0000     0.000206
# parent_child       small      0.0000       0.432      0.0000     0.000382
# multi_query        small      0.0000       1.886      0.0000     0.000175

# %% [markdown]
# ## 6 · Display results

# %%
import json
import pandas as pd
from pathlib import Path

# Anchor to repo root — works in both Colab (/content/rag-benchmark) and VS Code
results_dir = Path.cwd() / "results" / "benchmark_tables"

# Only look for benchmark run files — exclude QA cache files (qa_*.json)
run_files    = sorted(results_dir.glob("run_*.json"))
summary_file = results_dir / "summary.json"

if not run_files and not summary_file.exists():
    print("No benchmark results yet — run Cell 5 first, then come back here.")
else:
    rows = []
    # Prefer summary.json (written after all runs complete); fall back to per-run files
    if summary_file.exists():
        with open(summary_file) as f:
            data = json.load(f)
        rows = data if isinstance(data, list) else [data]
    else:
        for f in run_files:
            with open(f) as fh:
                rows.append(json.load(fh))

    records = []
    for r in rows:
        records.append({
            "Run ID":          r.get("run_id", "-"),
            "Architecture":    r.get("architecture", "-"),
            "Dataset":         r.get("dataset", "-"),
            "Recall@5":        round(r.get("retrieval_metrics", {}).get("recall_at_5",     0), 3),
            "MRR":             round(r.get("retrieval_metrics", {}).get("mrr",             0), 3),
            "P50 latency (s)": round(r.get("system_metrics",   {}).get("p50_latency",      0), 3),
            "Faithfulness":    round(r.get("quality_metrics",  {}).get("faithfulness",     0), 3),
            "Ans. relevancy":  round(r.get("quality_metrics",  {}).get("answer_relevancy", 0), 3),
            "$/query":         round(r.get("cost",             {}).get("per_query",        0), 5),
        })

    df = pd.DataFrame(records).sort_values(["Dataset", "Architecture"])
    print(f"Showing {len(df)} run(s) from {results_dir}\n")
    display(df)
# Out:
# Showing 5 run(s) from /content/RAG_Benchmarking/results/benchmark_tables
#    Run ID  Architecture Dataset  Recall@5  MRR  P50 latency (s)  Faithfulness  \
# 2       3         graph   small       0.0  0.0            0.011         0.000
# 1       2        hybrid   small       0.0  0.0            0.433         0.000
# 4       5   multi_query   small       0.0  0.0            1.886         0.000
# 3       4  parent_child   small       0.0  0.0            0.432         0.000
# 0       1        vector   small       0.0  0.0            0.489         0.977
#
#    Ans. relevancy  $/query
# 2           0.452  0.00021
# 1           0.687  0.00018
# 4           0.495  0.00018
# 3           0.617  0.00038
# 0           0.560  0.00018

# %% [markdown]
# ## 7 · Push results to GitHub

# %%
import subprocess
from google.colab import userdata

GITHUB_TOKEN = userdata.get("GITHUB_TOKEN")

# Configure git identity for this session
# !git config user.email "colab@rag-benchmark"
# !git config user.name  "Colab Runner"

# Stage only benchmark result JSONs — NOT indexes or raw data (gitignored, too large)
# !git add results/benchmark_tables/
# !git status --short

result = subprocess.run(
    ["git", "diff", "--cached", "--quiet"],
    capture_output=True
)

if result.returncode == 0:
    print("Nothing new to commit — results already up to date.")
else:
    import datetime
    timestamp = datetime.datetime.utcnow().strftime("%Y-%m-%d %H:%M UTC")
    # !git commit -m "chore: benchmark results {timestamp}"
    # !git push
    print("Results pushed to GitHub.")
# Out:
#  M decisions_log.md
# A  results/benchmark_tables/run_001_vector_small.json
# A  results/benchmark_tables/run_002_hybrid_small.json
# A  results/benchmark_tables/run_003_graph_small.json
# A  results/benchmark_tables/run_004_parent_child_small.json
# A  results/benchmark_tables/run_005_multi_query_small.json
# A  results/benchmark_tables/summary.json
# [main 15e65e3] chore: benchmark results 2026-03-16 19:34 UTC
#  6 files changed, 360 insertions(+)
#  create mode 100644 results/benchmark_tables/run_001_vector_small.json
#  create mode 100644 results/benchmark_tables/run_002_hybrid_small.json
#  create mode 100644 results/benchmark_tables/run_003_graph_small.json
#  create mode 100644 results/benchmark_tables/run_004_parent_child_small.json
#  create mode 100644 results/benchmark_tables/run_005_multi_query_small.json
#  create mode 100644 results/benchmark_tables/summary.json
# /tmp/ipykernel_7229/2720756406.py:23: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   timestamp = datetime.datetime.utcnow().strftime("%Y-%m-%d %H:%M UTC")
# remote: Permission to shrehs/RAG_Benchmarking.git denied to shrehs.
# fatal: unable to access 'https://github.com/shrehs/RAG_Benchmarking.git/': The requested URL returned error: 403
# Results pushed to GitHub.

# %% [markdown]
# <a href="https://colab.research.google.com/github/shrehs/RAG_Benchmarking/blob/main/colab_benchmark_dataset_large.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # RAG Benchmark — Google Colab Runner
#
# **Stack**
# | Component | Choice |
# |-----------|--------|
# | Generator LLM | `llama-3.1-8b-instant` via Groq (free, fast) |
# | Judge LLM | `llama-3.3-70b-versatile` via Groq (free, stronger) |
# | Embeddings | `BAAI/bge-large-en-v1.5` — runs on T4 GPU |
# | Vector store | FAISS (exact search) |
# | Evaluation | RAGAS (faithfulness + answer relevancy) |
#
# **Before running:**
# 1. Runtime → Change runtime type → **T4 GPU**
# 2. Open the 🔑 Secrets panel (left sidebar) and add:
#    - `GROQ_API_KEY` — free key from [console.groq.com](https://console.groq.com)
#    - `GITHUB_TOKEN` — a GitHub personal access token with `repo` scope (for pushing results)
# 3. Run cells top to bottom.

# %% [markdown]
# ## 1 · Clone repository

# %%
# ── Change this to your repo ──────────────────────────────────────────────────
GITHUB_USER = "shrehs"          # e.g. "shreya"
REPO_NAME   = "RAG_Benchmarking"          # e.g. "rag-benchmark"
BRANCH      = "main"
# ─────────────────────────────────────────────────────────────────────────────

import os
from google.colab import userdata

GITHUB_TOKEN = userdata.get("GITHUB_TOKEN")
REPO_URL = f"https://{GITHUB_TOKEN}@github.com/{GITHUB_USER}/{REPO_NAME}.git"

# Clone (or pull if already cloned from a previous session)
if not os.path.exists(f"/content/{REPO_NAME}/.git"):
    # !git clone --branch {BRANCH} {REPO_URL} /content/{REPO_NAME}
else:
    # !git -C /content/{REPO_NAME} pull

# %cd /content/{REPO_NAME}
print(f"Working directory: {os.getcwd()}")
# Out:
# Cloning into '/content/RAG_Benchmarking'...
# remote: Enumerating objects: 139, done.
# remote: Counting objects: 100% (139/139), done.
# remote: Compressing objects: 100% (107/107), done.
# remote: Total 139 (delta 48), reused 107 (delta 24), pack-reused 0 (from 0)
# Receiving objects: 100% (139/139), 989.85 KiB | 14.14 MiB/s, done.
# Resolving deltas: 100% (48/48), done.
# /content/RAG_Benchmarking
# Working directory: /content/RAG_Benchmarking

# %% [markdown]
# ## 2 · Install dependencies

# %%
# %%capture install_output
# Colab already has torch + numpy; install project-specific packages
# !pip install -q \
    groq \
    langchain-groq \
    langchain \
    langchain-community \
    langchain-huggingface \
    faiss-cpu \
    sentence-transformers \
    rank-bm25 \
    spacy \
    networkx \
    ragas \
    datasets \
    wikipedia-api \
    arxiv \
    psutil \
    python-dotenv \
    tiktoken

# !python -m spacy download -q en_core_web_sm

print("Dependencies installed.")

# %% [markdown]
# ## 3 · Configure secrets

# %%
import os
from google.colab import userdata

os.environ["GROQ_API_KEY"] = userdata.get("GROQ_API_KEY")

# Sanity check — never print the actual key
key = os.environ.get("GROQ_API_KEY", "")
print(f"GROQ_API_KEY set: {'yes (' + key[:8] + '...)' if key else 'NO — check Secrets'}")
# Out:
# GROQ_API_KEY set: yes (gsk_slcI...)

# %% [markdown]
# ## 4 · Verify environment

# %%
import torch, psutil

gpu = torch.cuda.get_device_name(0) if torch.cuda.is_available() else "None (CPU only)"
ram_gb = psutil.virtual_memory().total / 1e9

print(f"GPU  : {gpu}")
print(f"RAM  : {ram_gb:.1f} GB")
print(f"CUDA : {torch.version.cuda}")

# Confirm bge-large will use GPU
print(f"\nEmbeddings will use: {'CUDA (GPU)' if torch.cuda.is_available() else 'CPU'}")
# Out:
# GPU  : Tesla T4
# RAM  : 13.6 GB
# CUDA : 12.8
#
# Embeddings will use: CUDA (GPU)

# %% [markdown]
# ## 5 · Run benchmark
#
# Choose dataset: `small` (50 Wikipedia articles) · `medium` (500 arXiv papers) · `large` (2400 Kubernetes docs)

# %%
DATASET = "large"   # change to "medium" or "large" as needed

# !python run_benchmark.py --dataset {DATASET}
# Out:
# ============================================================
# RAG BENCHMARK — 5 experiments
# Started: 2026-03-20 17:17 UTC
# Dry run: False
# ============================================================
#
# ============================================================
# RUN-001 | VECTOR × LARGE
# ============================================================
# [run] Loading dataset: large
# [run] Loaded 100 documents
# [run] Generating QA pairs for large...
# /usr/local/lib/python3.12/dist-packages/instructor/providers/gemini/client.py:5: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   import google.generativeai as genai  # type: ignore[import-not-found]
# [ragas_eval] RAGAS not installed — using simple extraction fallback
# [run] Building index...
# [VectorRAG] Indexing 100 documents...
# [VectorRAG] 100 chunks created
# [embedder] Loading BAAI/bge-large-en-v1.5 on cpu...
# modules.json: 100% 349/349 [00:00<00:00, 2.22MB/s]
# config_sentence_transformers.json: 100% 124/124 [00:00<00:00, 613kB/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md: 94.6kB [00:00, 71.6MB/s]
# sentence_bert_config.json: 100% 52.0/52.0 [00:00<00:00, 270kB/s]
# config.json: 100% 779/779 [00:00<00:00, 5.96MB/s]
# model.safetensors: 100% 1.34G/1.34G [00:07<00:00, 186MB/s]
# Loading weights: 100% 391/391 [00:00<00:00, 1005.46it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: BAAI/bge-large-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json: 100% 366/366 [00:00<00:00, 2.49MB/s]
# vocab.txt: 232kB [00:00, 13.1MB/s]
# tokenizer.json: 711kB [00:00, 49.1MB/s]
# special_tokens_map.json: 100% 125/125 [00:00<00:00, 901kB/s]
# config.json: 100% 191/191 [00:00<00:00, 1.05MB/s]
# Batches: 100% 7/7 [02:50<00:00, 24.38s/it]
# [VectorRAG] FAISS index built: 100 vectors
# [VectorRAG] Index saved to /content/RAG_Benchmarking/results/indexes/vector/large
# [run] Indexing complete in 186.9s
# [run] Measuring latency...
# [latency] Running 1 warmup queries...
# [latency] Running 5 timed queries...
# [latency] P50=0.421s  P95=0.434s  Throughput=2.4q/s  Peak RAM=2403MB
# [run] Computing retrieval metrics...
# [run] Running RAGAS evaluation...
# [ragas_eval] Evaluating 20 QA pairs with judge=llama-3.1-8b-instant...
# [ragas_eval] 10/20 queries processed...
# [ragas_eval] 20/20 queries processed...
# Loading weights: 100% 391/391 [00:00<00:00, 953.61it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: BAAI/bge-large-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Evaluating:   0% 0/20 [00:00<?, ?it/s]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:   5% 1/20 [00:02<00:51,  2.72s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  10% 2/20 [00:06<00:58,  3.27s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  15% 3/20 [00:10<00:59,  3.48s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  20% 4/20 [00:14<01:02,  3.93s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  25% 5/20 [00:18<00:57,  3.82s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  30% 6/20 [00:23<00:57,  4.11s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  35% 7/20 [00:26<00:51,  3.95s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  40% 8/20 [00:30<00:46,  3.89s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  45% 9/20 [00:34<00:44,  4.09s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  50% 10/20 [00:38<00:39,  3.94s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  55% 11/20 [00:43<00:37,  4.19s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  60% 12/20 [00:46<00:32,  4.01s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  65% 13/20 [00:50<00:27,  3.90s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  70% 14/20 [00:55<00:25,  4.19s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  75% 15/20 [01:00<00:21,  4.33s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  80% 16/20 [01:03<00:16,  4.10s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  85% 17/20 [01:08<00:13,  4.36s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  90% 18/20 [01:12<00:08,  4.11s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  95% 19/20 [01:16<00:04,  4.26s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating: 100% 20/20 [01:20<00:00,  4.03s/it]
# [log_results] ✅ Appended RUN-001 to /content/RAG_Benchmarking/decisions_log.md
#
# [run] ✅ RUN-001 complete
# [run]    Recall@5: 0.0000
# [run]    P50 Latency: 0.421s
# [run]    Faithfulness: 0.0000
# [run]    Results: /content/RAG_Benchmarking/results/benchmark_tables/run_001_vector_large.json
#
# ============================================================
# RUN-002 | HYBRID × LARGE
# ============================================================
# [run] Loading dataset: large
# [run] Loaded 100 documents
# [run] Loaded 20 QA pairs from cache
# [run] Building index...
# [HybridRAG] Indexing 100 documents (alpha=0.5)...
# [HybridRAG] 100 chunks created
# [embedder] Loading BAAI/bge-large-en-v1.5 on cpu...
# Loading weights: 100% 391/391 [00:00<00:00, 918.55it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: BAAI/bge-large-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Batches: 100% 7/7 [02:52<00:00, 24.62s/it]
# [HybridRAG] FAISS + BM25 index built: 100 vectors
# [run] Indexing complete in 174.3s
# [run] Measuring latency...
# [latency] Running 1 warmup queries...
# [latency] Running 5 timed queries...
# [latency] P50=0.417s  P95=0.445s  Throughput=2.4q/s  Peak RAM=4745MB
# [run] Computing retrieval metrics...
# [run] Running RAGAS evaluation...
# [ragas_eval] Evaluating 20 QA pairs with judge=llama-3.1-8b-instant...
# [ragas_eval] 10/20 queries processed...
# [ragas_eval] 20/20 queries processed...
# Loading weights: 100% 391/391 [00:00<00:00, 1006.63it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: BAAI/bge-large-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Evaluating:   0% 0/20 [00:00<?, ?it/s]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:   5% 1/20 [00:02<00:53,  2.80s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  10% 2/20 [00:06<01:01,  3.40s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  15% 3/20 [00:10<00:58,  3.44s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  20% 4/20 [00:14<01:03,  3.99s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  25% 5/20 [00:19<01:03,  4.22s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  30% 6/20 [00:23<00:56,  4.01s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  35% 7/20 [00:26<00:50,  3.86s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  40% 8/20 [00:31<00:50,  4.17s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  45% 9/20 [00:35<00:44,  4.03s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  50% 10/20 [00:39<00:42,  4.24s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  55% 11/20 [00:43<00:36,  4.02s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  60% 12/20 [00:47<00:31,  3.90s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  65% 13/20 [00:51<00:29,  4.15s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  70% 14/20 [00:56<00:25,  4.30s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  75% 15/20 [01:00<00:20,  4.12s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  80% 16/20 [01:05<00:17,  4.39s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  85% 17/20 [01:08<00:12,  4.13s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  90% 18/20 [01:13<00:08,  4.28s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  95% 19/20 [01:18<00:04,  4.44s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating: 100% 20/20 [01:21<00:00,  4.10s/it]
# [log_results] ✅ Appended RUN-002 to /content/RAG_Benchmarking/decisions_log.md
#
# [run] ✅ RUN-002 complete
# [run]    Recall@5: 0.0000
# [run]    P50 Latency: 0.417s
# [run]    Faithfulness: 0.0000
# [run]    Results: /content/RAG_Benchmarking/results/benchmark_tables/run_002_hybrid_large.json
#
# ============================================================
# RUN-003 | GRAPH × LARGE
# ============================================================
# [run] Loading dataset: large
# [run] Loaded 100 documents
# [run] Loaded 20 QA pairs from cache
# [run] Building index...
# [GraphRAG] Indexing 100 documents...
# [GraphRAG] 100 chunks — extracting entities...
# [GraphRAG] 0 valid entities (freq >= 2) from 0 total
# [GraphRAG] Graph: 0 nodes, 0 edges
# [run] Indexing complete in 4.2s
# [run] Measuring latency...
# [latency] Running 1 warmup queries...
# [latency] Running 5 timed queries...
# [latency] P50=0.007s  P95=0.008s  Throughput=137.9q/s  Peak RAM=5969MB
# [run] Computing retrieval metrics...
# [run] Running RAGAS evaluation...
# [ragas_eval] Evaluating 20 QA pairs with judge=llama-3.1-8b-instant...
# [ragas_eval] 10/20 queries processed...
# [ragas_eval] 20/20 queries processed...
# Loading weights: 100% 391/391 [00:00<00:00, 923.59it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: BAAI/bge-large-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Evaluating:   0% 0/20 [00:00<?, ?it/s]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:   5% 1/20 [00:03<01:12,  3.80s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  10% 2/20 [00:07<01:08,  3.80s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  15% 3/20 [00:12<01:09,  4.12s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  20% 4/20 [00:16<01:09,  4.35s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  25% 5/20 [00:20<01:02,  4.17s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  30% 6/20 [00:24<00:55,  3.99s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  35% 7/20 [00:28<00:54,  4.17s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  40% 8/20 [00:33<00:52,  4.37s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  45% 9/20 [00:37<00:45,  4.16s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  50% 10/20 [00:42<00:43,  4.33s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  55% 11/20 [00:45<00:37,  4.13s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  60% 12/20 [00:49<00:31,  3.96s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  65% 13/20 [00:54<00:29,  4.24s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  70% 14/20 [00:58<00:26,  4.36s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  75% 15/20 [01:03<00:22,  4.49s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  80% 16/20 [01:08<00:18,  4.55s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  85% 17/20 [01:11<00:12,  4.26s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  90% 18/20 [01:16<00:08,  4.37s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  95% 19/20 [01:21<00:04,  4.47s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating: 100% 20/20 [01:24<00:00,  4.24s/it]
# [log_results] ✅ Appended RUN-003 to /content/RAG_Benchmarking/decisions_log.md
#
# [run] ✅ RUN-003 complete
# [run]    Recall@5: 0.0000
# [run]    P50 Latency: 0.007s
# [run]    Faithfulness: 0.0000
# [run]    Results: /content/RAG_Benchmarking/results/benchmark_tables/run_003_graph_large.json
#
# ============================================================
# RUN-004 | PARENT_CHILD × LARGE
# ============================================================
# [run] Loading dataset: large
# [run] Loaded 100 documents
# [run] Loaded 20 QA pairs from cache
# [run] Building index...
# [ParentChildRAG] Indexing 100 documents...
# [ParentChildRAG] 100 parents, 190 children
# [embedder] Loading BAAI/bge-large-en-v1.5 on cpu...
# Loading weights: 100% 391/391 [00:00<00:00, 1047.60it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: BAAI/bge-large-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Batches: 100% 7/7 [01:54<00:00, 16.40s/it]
# Batches: 100% 6/6 [01:29<00:00, 14.89s/it]
# [ParentChildRAG] FAISS index built on 190 child vectors
# [run] Indexing complete in 206.4s
# [run] Measuring latency...
# [latency] Running 1 warmup queries...
# [latency] Running 5 timed queries...
# [latency] P50=0.430s  P95=0.439s  Throughput=2.4q/s  Peak RAM=8386MB
# [run] Computing retrieval metrics...
# [run] Running RAGAS evaluation...
# [ragas_eval] Evaluating 20 QA pairs with judge=llama-3.1-8b-instant...
# [ragas_eval] 10/20 queries processed...
# [ragas_eval] 20/20 queries processed...
# Loading weights: 100% 391/391 [00:00<00:00, 916.02it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: BAAI/bge-large-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Evaluating:   0% 0/20 [00:00<?, ?it/s]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:   5% 1/20 [00:03<01:10,  3.69s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  10% 2/20 [00:07<01:04,  3.58s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  15% 3/20 [00:10<01:00,  3.55s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  20% 4/20 [00:15<01:03,  3.97s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  25% 5/20 [00:20<01:05,  4.35s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  30% 6/20 [00:24<00:57,  4.12s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  35% 7/20 [00:27<00:51,  3.92s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  40% 8/20 [00:31<00:46,  3.90s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  45% 9/20 [00:35<00:45,  4.09s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  50% 10/20 [00:39<00:39,  3.93s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  55% 11/20 [00:44<00:38,  4.23s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  60% 12/20 [00:47<00:32,  4.01s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  65% 13/20 [00:51<00:27,  3.87s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  70% 14/20 [00:56<00:25,  4.18s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  75% 15/20 [01:00<00:20,  4.06s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  80% 16/20 [01:04<00:16,  4.21s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  85% 17/20 [01:09<00:13,  4.38s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  90% 18/20 [01:13<00:08,  4.20s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  95% 19/20 [01:16<00:04,  4.04s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating: 100% 20/20 [01:21<00:00,  4.08s/it]
# [log_results] ✅ Appended RUN-004 to /content/RAG_Benchmarking/decisions_log.md
#
# [run] ✅ RUN-004 complete
# [run]    Recall@5: 0.0000
# [run]    P50 Latency: 0.430s
# [run]    Faithfulness: 0.0000
# [run]    Results: /content/RAG_Benchmarking/results/benchmark_tables/run_004_parent_child_large.json
#
# ============================================================
# RUN-005 | MULTI_QUERY × LARGE
# ============================================================
# [run] Loading dataset: large
# [run] Loaded 100 documents
# [run] Loaded 20 QA pairs from cache
# [run] Building index...
# [MultiQueryRAG] Indexing 100 documents...
# [MultiQueryRAG] 100 chunks
# [embedder] Loading BAAI/bge-large-en-v1.5 on cpu...
# Loading weights: 100% 391/391 [00:00<00:00, 1097.58it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: BAAI/bge-large-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Batches: 100% 7/7 [02:53<00:00, 24.72s/it]
# [MultiQueryRAG] FAISS index built: 100 vectors
# [run] Indexing complete in 175.4s
# [run] Measuring latency...
# [latency] Running 1 warmup queries...
# [latency] Running 5 timed queries...
# [latency] P50=1.815s  P95=1.964s  Throughput=0.6q/s  Peak RAM=10724MB
# [run] Computing retrieval metrics...
# [run] Running RAGAS evaluation...
# [ragas_eval] Evaluating 20 QA pairs with judge=llama-3.1-8b-instant...
# [ragas_eval] 10/20 queries processed...
# [ragas_eval] 20/20 queries processed...
# Loading weights: 100% 391/391 [00:00<00:00, 1013.86it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: BAAI/bge-large-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Evaluating:   0% 0/20 [00:00<?, ?it/s]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:   5% 1/20 [00:02<00:52,  2.76s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  10% 2/20 [00:06<01:01,  3.40s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  15% 3/20 [00:11<01:07,  3.96s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  20% 4/20 [00:14<01:01,  3.83s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  25% 5/20 [00:19<01:03,  4.23s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  30% 6/20 [00:23<00:56,  4.01s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  35% 7/20 [00:27<00:50,  3.89s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  40% 8/20 [00:32<00:51,  4.26s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  45% 9/20 [00:35<00:44,  4.03s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  50% 10/20 [00:39<00:39,  3.92s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  55% 11/20 [00:43<00:35,  3.91s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  60% 12/20 [00:47<00:32,  4.12s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  65% 13/20 [00:51<00:27,  3.99s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  70% 14/20 [00:56<00:25,  4.25s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  75% 15/20 [01:00<00:20,  4.11s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  80% 16/20 [01:04<00:17,  4.31s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  85% 17/20 [01:08<00:12,  4.15s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  90% 18/20 [01:13<00:08,  4.30s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  95% 19/20 [01:16<00:04,  4.11s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating: 100% 20/20 [01:21<00:00,  4.07s/it]
# [log_results] ✅ Appended RUN-005 to /content/RAG_Benchmarking/decisions_log.md
#
# [run] ✅ RUN-005 complete
# [run]    Recall@5: 0.0000
# [run]    P50 Latency: 1.815s
# [run]    Faithfulness: 0.0000
# [run]    Results: /content/RAG_Benchmarking/results/benchmark_tables/run_005_multi_query_large.json
#
# ============================================================
# ALL RUNS COMPLETE
# Summary: /content/RAG_Benchmarking/results/benchmark_tables/summary.json
# Full log: decisions_log.md
# ============================================================
#
# Architecture       Dataset    Recall@5     P50 (s)    Faith.     $/query
# ------------------------------------------------------------------------
# vector             large      0.0000       0.421      0.0000     0.000106
# hybrid             large      0.0000       0.417      0.0000     0.000109
# graph              large      0.0000       0.007      0.0000     0.000119
# parent_child       large      0.0000       0.430      0.0000     0.000106
# multi_query        large      0.0000       1.815      0.0000     0.000128

# %% [markdown]
# ## 6 · Display results

# %%
import json
import pandas as pd
from pathlib import Path

# Anchor to repo root — works in both Colab (/content/rag-benchmark) and VS Code
results_dir = Path.cwd() / "results" / "benchmark_tables"

# Only look for benchmark run files — exclude QA cache files (qa_*.json)
run_files    = sorted(results_dir.glob("run_*.json"))
summary_file = results_dir / "summary.json"

if not run_files and not summary_file.exists():
    print("No benchmark results yet — run Cell 5 first, then come back here.")
else:
    rows = []
    # Prefer summary.json (written after all runs complete); fall back to per-run files
    if summary_file.exists():
        with open(summary_file) as f:
            data = json.load(f)
        rows = data if isinstance(data, list) else [data]
    else:
        for f in run_files:
            with open(f) as fh:
                rows.append(json.load(fh))

    records = []
    for r in rows:
        records.append({
            "Run ID":          r.get("run_id", "-"),
            "Architecture":    r.get("architecture", "-"),
            "Dataset":         r.get("dataset", "-"),
            "Recall@5":        round(r.get("retrieval_metrics", {}).get("recall_at_5",     0), 3),
            "MRR":             round(r.get("retrieval_metrics", {}).get("mrr",             0), 3),
            "P50 latency (s)": round(r.get("system_metrics",   {}).get("p50_latency",      0), 3),
            "Faithfulness":    round(r.get("quality_metrics",  {}).get("faithfulness",     0), 3),
            "Ans. relevancy":  round(r.get("quality_metrics",  {}).get("answer_relevancy", 0), 3),
            "$/query":         round(r.get("cost",             {}).get("per_query",        0), 5),
        })

    df = pd.DataFrame(records).sort_values(["Dataset", "Architecture"])
    print(f"Showing {len(df)} run(s) from {results_dir}\n")
    display(df)
# Out:
# Showing 5 run(s) from /content/RAG_Benchmarking/results/benchmark_tables
#    Run ID  Architecture Dataset  Recall@5  MRR  P50 latency (s)  Faithfulness  \
# 2       3         graph   large       0.0  0.0            0.007           0.0
# 1       2        hybrid   large       0.0  0.0            0.417           0.0
# 4       5   multi_query   large       0.0  0.0            1.815           0.0
# 3       4  parent_child   large       0.0  0.0            0.430           0.0
# 0       1        vector   large       0.0  0.0            0.421           0.0
#
#    Ans. relevancy  $/query
# 2           0.730  0.00012
# 1           0.714  0.00011
# 4           0.704  0.00013
# 3           0.708  0.00011
# 0           0.693  0.00011

# %% [markdown]
# ## 7 · Push results to GitHub

# %%
import subprocess
from google.colab import userdata

GITHUB_TOKEN = userdata.get("GITHUB_TOKEN")

# Configure git identity for this session
# !git config user.email "colab@rag-benchmark"
# !git config user.name  "Colab Runner"

# Stage only benchmark result JSONs — NOT indexes or raw data (gitignored, too large)
# !git add results/benchmark_tables/
# !git status --short

result = subprocess.run(
    ["git", "diff", "--cached", "--quiet"],
    capture_output=True
)

if result.returncode == 0:
    print("Nothing new to commit — results already up to date.")
else:
    import datetime
    timestamp = datetime.datetime.utcnow().strftime("%Y-%m-%d %H:%M UTC")
    # !git commit -m "chore: benchmark results {timestamp}"
    # !git push
    print("Results pushed to GitHub.")
# Out:
#  M decisions_log.md
# A  results/benchmark_tables/qa_large.json
# A  results/benchmark_tables/run_001_vector_large.json
# A  results/benchmark_tables/run_002_hybrid_large.json
# A  results/benchmark_tables/run_003_graph_large.json
# A  results/benchmark_tables/run_004_parent_child_large.json
# A  results/benchmark_tables/run_005_multi_query_large.json
# A  results/benchmark_tables/summary.json
# [main 24ec6a9] chore: benchmark results 2026-03-20 17:58 UTC
#  7 files changed, 434 insertions(+)
#  create mode 100644 results/benchmark_tables/qa_large.json
#  create mode 100644 results/benchmark_tables/run_001_vector_large.json
#  create mode 100644 results/benchmark_tables/run_002_hybrid_large.json
#  create mode 100644 results/benchmark_tables/run_003_graph_large.json
#  create mode 100644 results/benchmark_tables/run_004_parent_child_large.json
#  create mode 100644 results/benchmark_tables/run_005_multi_query_large.json
#  create mode 100644 results/benchmark_tables/summary.json
# /tmp/ipykernel_3010/2720756406.py:23: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   timestamp = datetime.datetime.utcnow().strftime("%Y-%m-%d %H:%M UTC")
# remote: Permission to shrehs/RAG_Benchmarking.git denied to shrehs.
# fatal: unable to access 'https://github.com/shrehs/RAG_Benchmarking.git/': The requested URL returned error: 403
# Results pushed to GitHub.

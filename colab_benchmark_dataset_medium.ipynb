# %% [markdown]
# <a href="https://colab.research.google.com/github/shrehs/RAG_Benchmarking/blob/main/colab_benchmark_dataset_medium.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # RAG Benchmark — Google Colab Runner
#
# **Stack**
# | Component | Choice |
# |-----------|--------|
# | Generator LLM | `llama-3.1-8b-instant` via Groq (free, fast) |
# | Judge LLM | `llama-3.3-70b-versatile` via Groq (free, stronger) |
# | Embeddings | `BAAI/bge-large-en-v1.5` — runs on T4 GPU |
# | Vector store | FAISS (exact search) |
# | Evaluation | RAGAS (faithfulness + answer relevancy) |
#
# **Before running:**
# 1. Runtime → Change runtime type → **T4 GPU**
# 2. Open the 🔑 Secrets panel (left sidebar) and add:
#    - `GROQ_API_KEY` — free key from [console.groq.com](https://console.groq.com)
#    - `GITHUB_TOKEN` — a GitHub personal access token with `repo` scope (for pushing results)
# 3. Run cells top to bottom.

# %% [markdown]
# ## 1 · Clone repository

# %%
# ── Change this to your repo ──────────────────────────────────────────────────
GITHUB_USER = "shrehs"
REPO_NAME   = "RAG_Benchmarking"          # e.g. "rag-benchmark"
BRANCH      = "main"
# ─────────────────────────────────────────────────────────────────────────────

import os
from google.colab import userdata

GITHUB_TOKEN = userdata.get("GITHUB_TOKEN")
REPO_URL = f"https://{GITHUB_TOKEN}@github.com/{GITHUB_USER}/{REPO_NAME}.git"

# Clone (or pull if already cloned from a previous session)
if not os.path.exists(f"/content/{REPO_NAME}/.git"):
    # !git clone --branch {BRANCH} {REPO_URL} /content/{REPO_NAME}
else:
    # !git -C /content/{REPO_NAME} pull

# %cd /content/{REPO_NAME}
print(f"Working directory: {os.getcwd()}")
# Out:
# Cloning into '/content/RAG_Benchmarking'...
# remote: Enumerating objects: 136, done.
# remote: Counting objects: 100% (136/136), done.
# remote: Compressing objects: 100% (104/104), done.
# remote: Total 136 (delta 45), reused 107 (delta 24), pack-reused 0 (from 0)
# Receiving objects: 100% (136/136), 990.04 KiB | 26.76 MiB/s, done.
# Resolving deltas: 100% (45/45), done.
# /content/RAG_Benchmarking
# Working directory: /content/RAG_Benchmarking

# %% [markdown]
# ## 2 · Install dependencies

# %%
# %%capture install_output
# Colab already has torch + numpy; install project-specific packages
# !pip install -q \
    groq \
    langchain-groq \
    langchain \
    langchain-community \
    langchain-huggingface \
    faiss-cpu \
    sentence-transformers \
    rank-bm25 \
    spacy \
    networkx \
    ragas \
    datasets \
    wikipedia-api \
    arxiv \
    psutil \
    python-dotenv \
    tiktoken

# !python -m spacy download -q en_core_web_sm

print("Dependencies installed.")

# %% [markdown]
# ## 3 · Configure secrets

# %%
import os
from google.colab import userdata

os.environ["GROQ_API_KEY"] = userdata.get("GROQ_API_KEY")

# Sanity check — never print the actual key
key = os.environ.get("GROQ_API_KEY", "")
print(f"GROQ_API_KEY set: {'yes (' + key[:8] + '...)' if key else 'NO — check Secrets'}")
# Out:
# GROQ_API_KEY set: yes (gsk_slcI...)

# %% [markdown]
# ## 4 · Verify environment

# %%
import torch, psutil

gpu = torch.cuda.get_device_name(0) if torch.cuda.is_available() else "None (CPU only)"
ram_gb = psutil.virtual_memory().total / 1e9

print(f"GPU  : {gpu}")
print(f"RAM  : {ram_gb:.1f} GB")
print(f"CUDA : {torch.version.cuda}")

# Confirm bge-large will use GPU
print(f"\nEmbeddings will use: {'CUDA (GPU)' if torch.cuda.is_available() else 'CPU'}")
# Out:
# GPU  : Tesla T4
# RAM  : 13.6 GB
# CUDA : 12.8
#
# Embeddings will use: CUDA (GPU)

# %% [markdown]
# ## 5 · Run benchmark
#
# Choose dataset: `small` (50 Wikipedia articles) · `medium` (500 arXiv papers) · `large` (2400 Kubernetes docs)

# %%
DATASET = "medium"   # change to "medium" or "large" as needed

# !python run_benchmark.py --dataset {DATASET}
# Out:
# ============================================================
# RAG BENCHMARK — 5 experiments
# Started: 2026-03-17 14:50 UTC
# Dry run: False
# ============================================================
#
# ============================================================
# RUN-001 | VECTOR × MEDIUM
# ============================================================
# [run] Loading dataset: medium
# [run] Loaded 498 documents
# [run] Generating QA pairs for medium...
# /usr/local/lib/python3.12/dist-packages/instructor/providers/gemini/client.py:5: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   import google.generativeai as genai  # type: ignore[import-not-found]
# [ragas_eval] RAGAS not installed — using simple extraction fallback
# [run] Building index...
# [VectorRAG] Indexing 498 documents...
# [VectorRAG] 498 chunks created
# [embedder] Loading BAAI/bge-large-en-v1.5 on cpu...
# modules.json: 100% 349/349 [00:00<00:00, 1.73MB/s]
# config_sentence_transformers.json: 100% 124/124 [00:00<00:00, 654kB/s]
# README.md: 94.6kB [00:00, 83.6MB/s]
# sentence_bert_config.json: 100% 52.0/52.0 [00:00<00:00, 399kB/s]
# config.json: 100% 779/779 [00:00<00:00, 3.99MB/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors: 100% 1.34G/1.34G [00:12<00:00, 106MB/s]
# Loading weights: 100% 391/391 [00:00<00:00, 1036.96it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: BAAI/bge-large-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json: 100% 366/366 [00:00<00:00, 2.30MB/s]
# vocab.txt: 232kB [00:00, 70.4MB/s]
# tokenizer.json: 711kB [00:00, 161MB/s]
# special_tokens_map.json: 100% 125/125 [00:00<00:00, 864kB/s]
# config.json: 100% 191/191 [00:00<00:00, 934kB/s]
# Batches: 100% 7/7 [03:31<00:00, 30.18s/it]
# Batches: 100% 7/7 [03:30<00:00, 30.14s/it]
# Batches: 100% 7/7 [03:33<00:00, 30.56s/it]
# Batches: 100% 7/7 [03:33<00:00, 30.44s/it]
# Batches: 100% 7/7 [03:35<00:00, 30.84s/it]
# [VectorRAG] FAISS index built: 498 vectors
# [VectorRAG] Index saved to /content/RAG_Benchmarking/results/indexes/vector/medium
# [run] Indexing complete in 1089.7s
# [run] Measuring latency...
# [latency] Running 1 warmup queries...
# [latency] Running 5 timed queries...
# [latency] P50=0.474s  P95=0.571s  Throughput=2.0q/s  Peak RAM=2802MB
# [run] Computing retrieval metrics...
# [run] Running RAGAS evaluation...
# [ragas_eval] Evaluating 20 QA pairs with judge=llama-3.1-8b-instant...
# [ragas_eval] 10/20 queries processed...
# [ragas_eval] 20/20 queries processed...
# Loading weights: 100% 391/391 [00:00<00:00, 1078.90it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: BAAI/bge-large-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Evaluating:   0% 0/20 [00:00<?, ?it/s]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:   5% 1/20 [00:02<00:55,  2.90s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  10% 2/20 [00:05<00:52,  2.93s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  15% 3/20 [00:09<00:59,  3.47s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  20% 4/20 [00:15<01:05,  4.11s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  25% 5/20 [00:18<01:00,  4.03s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  30% 6/20 [00:24<01:01,  4.38s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  35% 7/20 [00:27<00:55,  4.24s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  40% 8/20 [00:32<00:50,  4.20s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  45% 9/20 [00:36<00:45,  4.15s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  50% 10/20 [00:40<00:41,  4.13s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  55% 11/20 [00:44<00:37,  4.14s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  60% 12/20 [00:48<00:32,  4.06s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  65% 13/20 [00:52<00:28,  4.10s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  70% 14/20 [00:59<00:30,  5.01s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  75% 15/20 [01:03<00:23,  4.69s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  80% 16/20 [01:07<00:18,  4.56s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  85% 17/20 [01:11<00:13,  4.37s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  90% 18/20 [01:15<00:08,  4.30s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  95% 19/20 [01:19<00:04,  4.25s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating: 100% 20/20 [01:23<00:00,  4.20s/it]
# [log_results] ✅ Appended RUN-001 to /content/RAG_Benchmarking/decisions_log.md
#
# [run] ✅ RUN-001 complete
# [run]    Recall@5: 0.0000
# [run]    P50 Latency: 0.474s
# [run]    Faithfulness: 0.0000
# [run]    Results: /content/RAG_Benchmarking/results/benchmark_tables/run_001_vector_medium.json
#
# ============================================================
# RUN-002 | HYBRID × MEDIUM
# ============================================================
# [run] Loading dataset: medium
# [run] Loaded 498 documents
# [run] Loaded 20 QA pairs from cache
# [run] Building index...
# [HybridRAG] Indexing 498 documents (alpha=0.5)...
# [HybridRAG] 498 chunks created
# [embedder] Loading BAAI/bge-large-en-v1.5 on cpu...
# Loading weights: 100% 391/391 [00:00<00:00, 962.85it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: BAAI/bge-large-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Batches: 100% 7/7 [03:24<00:00, 29.21s/it]
# Batches: 100% 7/7 [03:27<00:00, 29.70s/it]
# Batches: 100% 7/7 [03:36<00:00, 30.88s/it]
# Batches: 100% 7/7 [03:29<00:00, 29.97s/it]
# Batches: 100% 7/7 [03:38<00:00, 31.23s/it]
# [HybridRAG] FAISS + BM25 index built: 498 vectors
# [run] Indexing complete in 1061.8s
# [run] Measuring latency...
# [latency] Running 1 warmup queries...
# [latency] Running 5 timed queries...
# [latency] P50=0.425s  P95=0.472s  Throughput=2.3q/s  Peak RAM=5252MB
# [run] Computing retrieval metrics...
# [run] Running RAGAS evaluation...
# [ragas_eval] Evaluating 20 QA pairs with judge=llama-3.1-8b-instant...
# [ragas_eval] 10/20 queries processed...
# [ragas_eval] 20/20 queries processed...
# Loading weights: 100% 391/391 [00:00<00:00, 912.43it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: BAAI/bge-large-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Evaluating:   0% 0/20 [00:00<?, ?it/s]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:   5% 1/20 [00:02<00:55,  2.93s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  10% 2/20 [00:05<00:51,  2.86s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  15% 3/20 [00:10<00:59,  3.50s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  20% 4/20 [00:15<01:05,  4.10s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  25% 5/20 [00:18<01:00,  4.04s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  30% 6/20 [00:24<01:01,  4.40s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  35% 7/20 [00:28<00:55,  4.28s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  40% 8/20 [00:32<00:51,  4.30s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  45% 9/20 [00:36<00:46,  4.20s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  50% 10/20 [00:40<00:41,  4.14s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  55% 11/20 [00:44<00:37,  4.16s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  60% 12/20 [00:48<00:33,  4.14s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  65% 13/20 [00:54<00:31,  4.49s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  70% 14/20 [00:58<00:26,  4.46s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  75% 15/20 [01:02<00:21,  4.38s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  80% 16/20 [01:06<00:17,  4.30s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  85% 17/20 [01:10<00:12,  4.20s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  90% 18/20 [01:14<00:08,  4.15s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  95% 19/20 [01:19<00:04,  4.47s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating: 100% 20/20 [01:22<00:00,  4.14s/it]
# [log_results] ✅ Appended RUN-002 to /content/RAG_Benchmarking/decisions_log.md
#
# [run] ✅ RUN-002 complete
# [run]    Recall@5: 0.0000
# [run]    P50 Latency: 0.425s
# [run]    Faithfulness: 0.0000
# [run]    Results: /content/RAG_Benchmarking/results/benchmark_tables/run_002_hybrid_medium.json
#
# ============================================================
# RUN-003 | GRAPH × MEDIUM
# ============================================================
# [run] Loading dataset: medium
# [run] Loaded 498 documents
# [run] Loaded 20 QA pairs from cache
# [run] Building index...
# [GraphRAG] Indexing 498 documents...
# [GraphRAG] 498 chunks — extracting entities...
# [GraphRAG] 224 valid entities (freq >= 2) from 1525 total
# [GraphRAG] Graph: 224 nodes, 483 edges
# [run] Indexing complete in 19.7s
# [run] Measuring latency...
# [latency] Running 1 warmup queries...
# [latency] Running 5 timed queries...
# [latency] P50=0.035s  P95=0.038s  Throughput=29.6q/s  Peak RAM=1603MB
# [run] Computing retrieval metrics...
# [run] Running RAGAS evaluation...
# [ragas_eval] Evaluating 20 QA pairs with judge=llama-3.1-8b-instant...
# [ragas_eval] 10/20 queries processed...
# [ragas_eval] 20/20 queries processed...
# Loading weights: 100% 391/391 [00:00<00:00, 1093.13it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: BAAI/bge-large-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Evaluating:   0% 0/20 [00:00<?, ?it/s]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:   5% 1/20 [00:03<01:05,  3.45s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  10% 2/20 [00:06<00:55,  3.08s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  15% 3/20 [00:10<01:00,  3.57s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  20% 4/20 [00:15<01:08,  4.30s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  25% 5/20 [00:19<01:03,  4.22s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  30% 6/20 [00:23<00:58,  4.16s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  35% 7/20 [00:29<00:57,  4.45s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  40% 8/20 [00:33<00:51,  4.33s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  45% 9/20 [00:37<00:46,  4.24s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  50% 10/20 [00:41<00:41,  4.16s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  55% 11/20 [00:45<00:36,  4.08s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  60% 12/20 [00:49<00:32,  4.07s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  65% 13/20 [00:54<00:30,  4.39s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  70% 14/20 [00:58<00:25,  4.27s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  75% 15/20 [01:02<00:21,  4.24s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  80% 16/20 [01:06<00:16,  4.19s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  85% 17/20 [01:10<00:12,  4.16s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  90% 18/20 [01:15<00:08,  4.41s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  95% 19/20 [01:19<00:04,  4.30s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating: 100% 20/20 [01:23<00:00,  4.18s/it]
# [log_results] ✅ Appended RUN-003 to /content/RAG_Benchmarking/decisions_log.md
#
# [run] ✅ RUN-003 complete
# [run]    Recall@5: 0.0000
# [run]    P50 Latency: 0.035s
# [run]    Faithfulness: 0.0000
# [run]    Results: /content/RAG_Benchmarking/results/benchmark_tables/run_003_graph_medium.json
#
# ============================================================
# RUN-004 | PARENT_CHILD × MEDIUM
# ============================================================
# [run] Loading dataset: medium
# [run] Loaded 498 documents
# [run] Loaded 20 QA pairs from cache
# [run] Building index...
# [ParentChildRAG] Indexing 498 documents...
# [ParentChildRAG] 498 parents, 680 children
# [embedder] Loading BAAI/bge-large-en-v1.5 on cpu...
# Loading weights: 100% 391/391 [00:00<00:00, 932.76it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: BAAI/bge-large-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Batches: 100% 7/7 [02:46<00:00, 23.72s/it]
# Batches: 100% 7/7 [02:26<00:00, 20.99s/it]
# Batches: 100% 7/7 [02:51<00:00, 24.48s/it]
# Batches: 100% 7/7 [02:45<00:00, 23.58s/it]
# Batches: 100% 7/7 [02:46<00:00, 23.73s/it]
# Batches: 100% 7/7 [02:40<00:00, 22.93s/it]
# Batches: 100% 5/5 [02:13<00:00, 26.67s/it]
# [ParentChildRAG] FAISS index built on 680 child vectors
# [run] Indexing complete in 1113.6s
# [run] Measuring latency...
# [latency] Running 1 warmup queries...
# [latency] Running 5 timed queries...
# [latency] P50=0.550s  P95=0.609s  Throughput=1.8q/s  Peak RAM=4005MB
# [run] Computing retrieval metrics...
# [run] Running RAGAS evaluation...
# [ragas_eval] Evaluating 20 QA pairs with judge=llama-3.1-8b-instant...
# [ragas_eval] 10/20 queries processed...
# [ragas_eval] 20/20 queries processed...
# Loading weights: 100% 391/391 [00:00<00:00, 941.29it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: BAAI/bge-large-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Evaluating:   0% 0/20 [00:00<?, ?it/s]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:   5% 1/20 [00:02<00:54,  2.84s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  10% 2/20 [00:06<01:04,  3.56s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  15% 3/20 [00:09<00:55,  3.24s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  20% 4/20 [00:15<01:10,  4.38s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  25% 5/20 [00:19<01:03,  4.23s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  30% 6/20 [00:23<00:58,  4.18s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  35% 7/20 [00:27<00:53,  4.13s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  40% 8/20 [00:32<00:49,  4.12s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  45% 9/20 [00:35<00:44,  4.06s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  50% 10/20 [00:40<00:40,  4.07s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  55% 11/20 [00:44<00:36,  4.05s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  60% 12/20 [00:49<00:34,  4.36s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  65% 13/20 [00:53<00:30,  4.38s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  70% 14/20 [00:59<00:29,  4.88s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  75% 15/20 [01:03<00:23,  4.66s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  80% 16/20 [01:07<00:17,  4.45s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  85% 17/20 [01:11<00:12,  4.29s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  90% 18/20 [01:16<00:08,  4.40s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  95% 19/20 [01:20<00:04,  4.25s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating: 100% 20/20 [01:24<00:00,  4.21s/it]
# [log_results] ✅ Appended RUN-004 to /content/RAG_Benchmarking/decisions_log.md
#
# [run] ✅ RUN-004 complete
# [run]    Recall@5: 0.0000
# [run]    P50 Latency: 0.550s
# [run]    Faithfulness: 0.0000
# [run]    Results: /content/RAG_Benchmarking/results/benchmark_tables/run_004_parent_child_medium.json
#
# ============================================================
# RUN-005 | MULTI_QUERY × MEDIUM
# ============================================================
# [run] Loading dataset: medium
# [run] Loaded 498 documents
# [run] Loaded 20 QA pairs from cache
# [run] Building index...
# [MultiQueryRAG] Indexing 498 documents...
# [MultiQueryRAG] 498 chunks
# [embedder] Loading BAAI/bge-large-en-v1.5 on cpu...
# Loading weights: 100% 391/391 [00:00<00:00, 1064.19it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: BAAI/bge-large-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Batches: 100% 7/7 [03:25<00:00, 29.38s/it]
# Batches: 100% 7/7 [03:24<00:00, 29.22s/it]
# Batches: 100% 7/7 [03:38<00:00, 31.26s/it]
# Batches: 100% 7/7 [03:28<00:00, 29.79s/it]
# Batches: 100% 7/7 [03:34<00:00, 30.67s/it]
# [MultiQueryRAG] FAISS index built: 498 vectors
# [run] Indexing complete in 1056.5s
# [run] Measuring latency...
# [latency] Running 1 warmup queries...
# [latency] Running 5 timed queries...
# [latency] P50=1.816s  P95=2.332s  Throughput=0.5q/s  Peak RAM=6460MB
# [run] Computing retrieval metrics...
# [run] Running RAGAS evaluation...
# [ragas_eval] Evaluating 20 QA pairs with judge=llama-3.1-8b-instant...
# [ragas_eval] 10/20 queries processed...
# [ragas_eval] 20/20 queries processed...
# Loading weights: 100% 391/391 [00:00<00:00, 1147.37it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: BAAI/bge-large-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Evaluating:   0% 0/20 [00:00<?, ?it/s]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:   5% 1/20 [00:02<00:54,  2.85s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  10% 2/20 [00:05<00:52,  2.93s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  15% 3/20 [00:09<00:58,  3.42s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  20% 4/20 [00:14<01:05,  4.09s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  25% 5/20 [00:18<01:00,  4.03s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  30% 6/20 [00:24<01:01,  4.41s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  35% 7/20 [00:27<00:55,  4.24s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  40% 8/20 [00:32<00:50,  4.20s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  45% 9/20 [00:36<00:45,  4.14s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  50% 10/20 [00:39<00:40,  4.08s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  55% 11/20 [00:45<00:39,  4.39s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  60% 12/20 [00:49<00:34,  4.27s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  65% 13/20 [00:53<00:29,  4.24s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  70% 14/20 [01:00<00:30,  5.09s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  75% 15/20 [01:04<00:23,  4.74s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  80% 16/20 [01:09<00:19,  4.91s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  85% 17/20 [01:12<00:12,  4.31s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  90% 18/20 [01:17<00:08,  4.49s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating:  95% 19/20 [01:21<00:04,  4.39s/it]LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluating: 100% 20/20 [01:25<00:00,  4.28s/it]
# [log_results] ✅ Appended RUN-005 to /content/RAG_Benchmarking/decisions_log.md
#
# [run] ✅ RUN-005 complete
# [run]    Recall@5: 0.0000
# [run]    P50 Latency: 1.816s
# [run]    Faithfulness: 0.0000
# [run]    Results: /content/RAG_Benchmarking/results/benchmark_tables/run_005_multi_query_medium.json
#
# ============================================================
# ALL RUNS COMPLETE
# Summary: /content/RAG_Benchmarking/results/benchmark_tables/summary.json
# Full log: decisions_log.md
# ============================================================
#
# Architecture       Dataset    Recall@5     P50 (s)    Faith.     $/query
# ------------------------------------------------------------------------
# vector             medium     0.0000       0.474      0.0000     0.000115
# hybrid             medium     0.0000       0.425      0.0000     0.000113
# graph              medium     0.0000       0.035      0.0000     0.000127
# parent_child       medium     0.0000       0.550      0.0000     0.000144
# multi_query        medium     0.0000       1.816      0.0000     0.000149

# %% [markdown]
# ## 6 · Display results

# %%
import json
import pandas as pd
from pathlib import Path

# Anchor to repo root — works in both Colab (/content/rag-benchmark) and VS Code
results_dir = Path.cwd() / "results" / "benchmark_tables"

# Only look for benchmark run files — exclude QA cache files (qa_*.json)
run_files    = sorted(results_dir.glob("run_*.json"))
summary_file = results_dir / "summary.json"

if not run_files and not summary_file.exists():
    print("No benchmark results yet — run Cell 5 first, then come back here.")
else:
    rows = []
    # Prefer summary.json (written after all runs complete); fall back to per-run files
    if summary_file.exists():
        with open(summary_file) as f:
            data = json.load(f)
        rows = data if isinstance(data, list) else [data]
    else:
        for f in run_files:
            with open(f) as fh:
                rows.append(json.load(fh))

    records = []
    for r in rows:
        records.append({
            "Run ID":          r.get("run_id", "-"),
            "Architecture":    r.get("architecture", "-"),
            "Dataset":         r.get("dataset", "-"),
            "Recall@5":        round(r.get("retrieval_metrics", {}).get("recall_at_5",     0), 3),
            "MRR":             round(r.get("retrieval_metrics", {}).get("mrr",             0), 3),
            "P50 latency (s)": round(r.get("system_metrics",   {}).get("p50_latency",      0), 3),
            "Faithfulness":    round(r.get("quality_metrics",  {}).get("faithfulness",     0), 3),
            "Ans. relevancy":  round(r.get("quality_metrics",  {}).get("answer_relevancy", 0), 3),
            "$/query":         round(r.get("cost",             {}).get("per_query",        0), 5),
        })

    df = pd.DataFrame(records).sort_values(["Dataset", "Architecture"])
    print(f"Showing {len(df)} run(s) from {results_dir}\n")
    display(df)
# Out:
# Showing 5 run(s) from /content/RAG_Benchmarking/results/benchmark_tables
#    Run ID  Architecture Dataset  Recall@5  MRR  P50 latency (s)  Faithfulness  \
# 2       3         graph  medium       0.0  0.0            0.035           0.0
# 1       2        hybrid  medium       0.0  0.0            0.425           0.0
# 4       5   multi_query  medium       0.0  0.0            1.816           0.0
# 3       4  parent_child  medium       0.0  0.0            0.550           0.0
# 0       1        vector  medium       0.0  0.0            0.474           0.0
#
#    Ans. relevancy  $/query
# 2           0.595  0.00013
# 1           0.614  0.00011
# 4           0.332  0.00015
# 3           0.263  0.00014
# 0           0.313  0.00012

# %% [markdown]
# ## 7 · Push results to GitHub

# %%
import subprocess
from google.colab import userdata

GITHUB_TOKEN = userdata.get("GITHUB_TOKEN")

# Configure git identity for this session
# !git config user.email "colab@rag-benchmark"
# !git config user.name  "Colab Runner"

# Stage only benchmark result JSONs — NOT indexes or raw data (gitignored, too large)
# !git add results/benchmark_tables/
# !git status --short

result = subprocess.run(
    ["git", "diff", "--cached", "--quiet"],
    capture_output=True
)

if result.returncode == 0:
    print("Nothing new to commit — results already up to date.")
else:
    import datetime
    timestamp = datetime.datetime.utcnow().strftime("%Y-%m-%d %H:%M UTC")
    # !git commit -m "chore: benchmark results {timestamp}"
    # !git push
    print("Results pushed to GitHub.")
# Out:
#  M decisions_log.md
# A  results/benchmark_tables/qa_medium.json
# A  results/benchmark_tables/run_001_vector_medium.json
# A  results/benchmark_tables/run_002_hybrid_medium.json
# A  results/benchmark_tables/run_003_graph_medium.json
# A  results/benchmark_tables/run_004_parent_child_medium.json
# A  results/benchmark_tables/run_005_multi_query_medium.json
# A  results/benchmark_tables/summary.json
# [main b5d7413] chore: benchmark results 2026-03-17 16:38 UTC
#  7 files changed, 434 insertions(+)
#  create mode 100644 results/benchmark_tables/qa_medium.json
#  create mode 100644 results/benchmark_tables/run_001_vector_medium.json
#  create mode 100644 results/benchmark_tables/run_002_hybrid_medium.json
#  create mode 100644 results/benchmark_tables/run_003_graph_medium.json
#  create mode 100644 results/benchmark_tables/run_004_parent_child_medium.json
#  create mode 100644 results/benchmark_tables/run_005_multi_query_medium.json
#  create mode 100644 results/benchmark_tables/summary.json
# /tmp/ipykernel_4072/2720756406.py:23: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   timestamp = datetime.datetime.utcnow().strftime("%Y-%m-%d %H:%M UTC")
# remote: Permission to shrehs/RAG_Benchmarking.git denied to shrehs.
# fatal: unable to access 'https://github.com/shrehs/RAG_Benchmarking.git/': The requested URL returned error: 403
# Results pushed to GitHub.
